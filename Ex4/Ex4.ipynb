# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'S:\Coding\Python\TimeSeries\Ex4\daily-min-temperatures.csv')

# %%
df
# Out:
#             Date  Temp
# 0     1981-01-01  20.7
# 1     1981-01-02  17.9
# 2     1981-01-03  18.8
# 3     1981-01-04  14.6
# 4     1981-01-05  15.8
# ...          ...   ...
# 3645  1990-12-27  14.0
# 3646  1990-12-28  13.6
# 3647  1990-12-29  13.5
# 3648  1990-12-30  15.7
# 3649  1990-12-31  13.0
#
# [3650 rows x 2 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'],format = '%Y-%m-%d')

# %%
df.set_index('Date',inplace = True)

# %%
plt.figure(figsize = (12,6))
sns.lineplot(df)
# Out:
# <Axes: xlabel='Date'>

# %%
df = df.resample('ME').asfreq()
df
# Out:
#             Temp
# Date
# 1981-01-31  15.4
# 1981-02-28  21.2
# 1981-03-31  15.8
# 1981-04-30   7.4
# 1981-05-31  12.8
# ...          ...
# 1990-08-31   7.9
# 1990-09-30  10.0
# 1990-10-31  14.8
# 1990-11-30  12.7
# 1990-12-31  13.0
#
# [120 rows x 1 columns]

# %%
plt.figure(figsize = (12,6))
sns.lineplot(df)
# Out:
# <Axes: xlabel='Date'>

# %%
df = df.resample('D')
df = df.interpolate(method = 'quadratic')
df
# Out:
#                  Temp
# Date
# 1981-01-31  15.400000
# 1981-02-01  15.795548
# 1981-02-02  16.177141
# 1981-02-03  16.544777
# 1981-02-04  16.898458
# ...               ...
# 1990-12-27  12.712159
# 1990-12-28  12.777199
# 1990-12-29  12.846853
# 1990-12-30  12.921119
# 1990-12-31  13.000000
#
# [3622 rows x 1 columns]

# %%
plt.figure(figsize = (12,6))
sns.lineplot(df)
# Out:
# <Axes: xlabel='Date'>
