# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
np.random.seed(42)

# %%
values = np.random.randn(100)

# %%
values
# Out:
# array([ 0.49671415, -0.1382643 ,  0.64768854,  1.52302986, -0.23415337,
#        -0.23413696,  1.57921282,  0.76743473, -0.46947439,  0.54256004,
#        -0.46341769, -0.46572975,  0.24196227, -1.91328024, -1.72491783,
#        -0.56228753, -1.01283112,  0.31424733, -0.90802408, -1.4123037 ,
#         1.46564877, -0.2257763 ,  0.0675282 , -1.42474819, -0.54438272,
#         0.11092259, -1.15099358,  0.37569802, -0.60063869, -0.29169375,
#        -0.60170661,  1.85227818, -0.01349722, -1.05771093,  0.82254491,
#        -1.22084365,  0.2088636 , -1.95967012, -1.32818605,  0.19686124,
#         0.73846658,  0.17136828, -0.11564828, -0.3011037 , -1.47852199,
#        -0.71984421, -0.46063877,  1.05712223,  0.34361829, -1.76304016,
#         0.32408397, -0.38508228, -0.676922  ,  0.61167629,  1.03099952,
#         0.93128012, -0.83921752, -0.30921238,  0.33126343,  0.97554513,
#        -0.47917424, -0.18565898, -1.10633497, -1.19620662,  0.81252582,
#         1.35624003, -0.07201012,  1.0035329 ,  0.36163603, -0.64511975,
#         0.36139561,  1.53803657, -0.03582604,  1.56464366, -2.6197451 ,
#         0.8219025 ,  0.08704707, -0.29900735,  0.09176078, -1.98756891,
#        -0.21967189,  0.35711257,  1.47789404, -0.51827022, -0.8084936 ,
#        -0.50175704,  0.91540212,  0.32875111, -0.5297602 ,  0.51326743,
#         0.09707755,  0.96864499, -0.70205309, -0.32766215, -0.39210815,
#        -1.46351495,  0.29612028,  0.26105527,  0.00511346, -0.23458713])

# %%
dates = pd.date_range(start = "2023-01-01", end = "2023-04-10",freq = "D")

# %%
dates
# Out:
# DatetimeIndex(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04',
#                '2023-01-05', '2023-01-06', '2023-01-07', '2023-01-08',
#                '2023-01-09', '2023-01-10', '2023-01-11', '2023-01-12',
#                '2023-01-13', '2023-01-14', '2023-01-15', '2023-01-16',
#                '2023-01-17', '2023-01-18', '2023-01-19', '2023-01-20',
#                '2023-01-21', '2023-01-22', '2023-01-23', '2023-01-24',
#                '2023-01-25', '2023-01-26', '2023-01-27', '2023-01-28',
#                '2023-01-29', '2023-01-30', '2023-01-31', '2023-02-01',
#                '2023-02-02', '2023-02-03', '2023-02-04', '2023-02-05',
#                '2023-02-06', '2023-02-07', '2023-02-08', '2023-02-09',
#                '2023-02-10', '2023-02-11', '2023-02-12', '2023-02-13',
#                '2023-02-14', '2023-02-15', '2023-02-16', '2023-02-17',
#                '2023-02-18', '2023-02-19', '2023-02-20', '2023-02-21',
#                '2023-02-22', '2023-02-23', '2023-02-24', '2023-02-25',
#                '2023-02-26', '2023-02-27', '2023-02-28', '2023-03-01',
#                '2023-03-02', '2023-03-03', '2023-03-04', '2023-03-05',
#                '2023-03-06', '2023-03-07', '2023-03-08', '2023-03-09',
#                '2023-03-10', '2023-03-11', '2023-03-12', '2023-03-13',
#                '2023-03-14', '2023-03-15', '2023-03-16', '2023-03-17',
#                '2023-03-18', '2023-03-19', '2023-03-20', '2023-03-21',
#                '2023-03-22', '2023-03-23', '2023-03-24', '2023-03-25',
#                '2023-03-26', '2023-03-27', '2023-03-28', '2023-03-29',
#                '2023-03-30', '2023-03-31', '2023-04-01', '2023-04-02',
#                '2023-04-03', '2023-04-04', '2023-04-05', '2023-04-06',
#                '2023-04-07', '2023-04-08', '2023-04-09', '2023-04-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(values,index=dates,columns=['value'])

# %%
df
# Out:
#                value
# 2023-01-01  0.496714
# 2023-01-02 -0.138264
# 2023-01-03  0.647689
# 2023-01-04  1.523030
# 2023-01-05 -0.234153
# ...              ...
# 2023-04-06 -1.463515
# 2023-04-07  0.296120
# 2023-04-08  0.261055
# 2023-04-09  0.005113
# 2023-04-10 -0.234587
#
# [100 rows x 1 columns]

# %%
df['value'].plot(kind='hist',bins=20,title='Value')
ax= plt.gca()
ax.spines['top'].set_visible(True)
ax.spines['right'].set_visible(True)
ax.spines['left'].set_visible(True)
ax.spines['bottom'].set_visible(True)
plt.show()

# %%
df['value'].plot(kind='line',figsize=(8,4),title='Value')
ax= plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(df['value'])
plt.xlabel("Date")
plt.ylabel("Value")
plt.title("Synthetic Time Series Dataset")
plt.show()

# %%
df['year'] = df.index.year
df['month'] = df.index.month
df['day'] = df.index.day
df['weekday'] = df.index.weekday
df
# Out:
#                value  year  month  day  weekday
# 2023-01-01  0.496714  2023      1    1        6
# 2023-01-02 -0.138264  2023      1    2        0
# 2023-01-03  0.647689  2023      1    3        1
# 2023-01-04  1.523030  2023      1    4        2
# 2023-01-05 -0.234153  2023      1    5        3
# ...              ...   ...    ...  ...      ...
# 2023-04-06 -1.463515  2023      4    6        3
# 2023-04-07  0.296120  2023      4    7        4
# 2023-04-08  0.261055  2023      4    8        5
# 2023-04-09  0.005113  2023      4    9        6
# 2023-04-10 -0.234587  2023      4   10        0
#
# [100 rows x 5 columns]

# %%
df['lag_1'] = df['value'].shift(1)
df
# Out:
#                value  year  month  day  weekday     lag_1
# 2023-01-01  0.496714  2023      1    1        6       NaN
# 2023-01-02 -0.138264  2023      1    2        0  0.496714
# 2023-01-03  0.647689  2023      1    3        1 -0.138264
# 2023-01-04  1.523030  2023      1    4        2  0.647689
# 2023-01-05 -0.234153  2023      1    5        3  1.523030
# ...              ...   ...    ...  ...      ...       ...
# 2023-04-06 -1.463515  2023      4    6        3 -0.392108
# 2023-04-07  0.296120  2023      4    7        4 -1.463515
# 2023-04-08  0.261055  2023      4    8        5  0.296120
# 2023-04-09  0.005113  2023      4    9        6  0.261055
# 2023-04-10 -0.234587  2023      4   10        0  0.005113
#
# [100 rows x 6 columns]

# %%
df['lag_2'] = df['value'].shift(2)
df
# Out:
#                value  year  month  day  weekday     lag_1     lag_2
# 2023-01-01  0.496714  2023      1    1        6       NaN       NaN
# 2023-01-02 -0.138264  2023      1    2        0  0.496714       NaN
# 2023-01-03  0.647689  2023      1    3        1 -0.138264  0.496714
# 2023-01-04  1.523030  2023      1    4        2  0.647689 -0.138264
# 2023-01-05 -0.234153  2023      1    5        3  1.523030  0.647689
# ...              ...   ...    ...  ...      ...       ...       ...
# 2023-04-06 -1.463515  2023      4    6        3 -0.392108 -0.327662
# 2023-04-07  0.296120  2023      4    7        4 -1.463515 -0.392108
# 2023-04-08  0.261055  2023      4    8        5  0.296120 -1.463515
# 2023-04-09  0.005113  2023      4    9        6  0.261055  0.296120
# 2023-04-10 -0.234587  2023      4   10        0  0.005113  0.261055
#
# [100 rows x 7 columns]

# %%
df['rolling_mean_5'] = df['value'].rolling(5).mean()
df['rolling_std_5'] = df['value'].rolling(5).std()
df['rolling_min_5'] = df['value'].rolling(5).min()
df['rolling_max_5'] = df['value'].rolling(5).max()
df
# Out:
#                value  year  month  day  weekday     lag_1     lag_2  \
# 2023-01-01  0.496714  2023      1    1        6       NaN       NaN
# 2023-01-02 -0.138264  2023      1    2        0  0.496714       NaN
# 2023-01-03  0.647689  2023      1    3        1 -0.138264  0.496714
# 2023-01-04  1.523030  2023      1    4        2  0.647689 -0.138264
# 2023-01-05 -0.234153  2023      1    5        3  1.523030  0.647689
# ...              ...   ...    ...  ...      ...       ...       ...
# 2023-04-06 -1.463515  2023      4    6        3 -0.392108 -0.327662
# 2023-04-07  0.296120  2023      4    7        4 -1.463515 -0.392108
# 2023-04-08  0.261055  2023      4    8        5  0.296120 -1.463515
# 2023-04-09  0.005113  2023      4    9        6  0.261055  0.296120
# 2023-04-10 -0.234587  2023      4   10        0  0.005113  0.261055
#
#             rolling_mean_5  rolling_std_5  rolling_min_5  rolling_max_5
# 2023-01-01             NaN            NaN            NaN            NaN
# 2023-01-02             NaN            NaN            NaN            NaN
# 2023-01-03             NaN            NaN            NaN            NaN
# 2023-01-04             NaN            NaN            NaN            NaN
# 2023-01-05        0.459003       0.708232      -0.234153       1.523030
# ...                    ...            ...            ...            ...
# 2023-04-06       -0.383339       0.880255      -1.463515       0.968645
# 2023-04-07       -0.517844       0.640848      -1.463515       0.296120
# 2023-04-08       -0.325222       0.712386      -1.463515       0.296120
# 2023-04-09       -0.258667       0.727486      -1.463515       0.296120
# 2023-04-10       -0.227163       0.723664      -1.463515       0.296120
#
# [100 rows x 11 columns]

# %%
fig, axs = plt.subplots(4, 1,figsize=(12,24)) 

axs[0].xaxis.set_major_formatter(mdates.DateFormatter('%b'))
axs[0].plot(df['rolling_mean_5'])
axs[0].set_title('Subplot 1') 

axs[1].xaxis.set_major_formatter(mdates.DateFormatter('%b'))
axs[1].plot(df['rolling_std_5'])
axs[1].set_title('Subplot 2') 

axs[2].xaxis.set_major_formatter(mdates.DateFormatter('%b'))
axs[2].plot(df['rolling_min_5'])
axs[2].set_title('Subplot 3') 

axs[3].xaxis.set_major_formatter(mdates.DateFormatter('%b'))
axs[3].plot(df['rolling_max_5'])
axs[3].set_title('Subplot 4') 

plt.tight_layout()
plt.show()

# %%
df['expanding_mean_5'] = df['value'].expanding().mean()
df['expanding_std_5'] = df['value'].expanding().std()
df['expanding_min_5'] = df['value'].expanding().min()
df['expanding_max_5'] = df['value'].expanding().max()
df
# Out:
#                value  year  month  day  weekday     lag_1     lag_2  \
# 2023-01-01  0.496714  2023      1    1        6       NaN       NaN
# 2023-01-02 -0.138264  2023      1    2        0  0.496714       NaN
# 2023-01-03  0.647689  2023      1    3        1 -0.138264  0.496714
# 2023-01-04  1.523030  2023      1    4        2  0.647689 -0.138264
# 2023-01-05 -0.234153  2023      1    5        3  1.523030  0.647689
# ...              ...   ...    ...  ...      ...       ...       ...
# 2023-04-06 -1.463515  2023      4    6        3 -0.392108 -0.327662
# 2023-04-07  0.296120  2023      4    7        4 -1.463515 -0.392108
# 2023-04-08  0.261055  2023      4    8        5  0.296120 -1.463515
# 2023-04-09  0.005113  2023      4    9        6  0.261055  0.296120
# 2023-04-10 -0.234587  2023      4   10        0  0.005113  0.261055
#
#             rolling_mean_5  rolling_std_5  rolling_min_5  rolling_max_5  \
# 2023-01-01             NaN            NaN            NaN            NaN
# 2023-01-02             NaN            NaN            NaN            NaN
# 2023-01-03             NaN            NaN            NaN            NaN
# 2023-01-04             NaN            NaN            NaN            NaN
# 2023-01-05        0.459003       0.708232      -0.234153       1.523030
# ...                    ...            ...            ...            ...
# 2023-04-06       -0.383339       0.880255      -1.463515       0.968645
# 2023-04-07       -0.517844       0.640848      -1.463515       0.296120
# 2023-04-08       -0.325222       0.712386      -1.463515       0.296120
# 2023-04-09       -0.258667       0.727486      -1.463515       0.296120
# 2023-04-10       -0.227163       0.723664      -1.463515       0.296120
#
#             expanding_mean_5  expanding_std_5  expanding_min_5  \
# 2023-01-01          0.496714              NaN         0.496714
# 2023-01-02          0.179225         0.448998        -0.138264
# 2023-01-03          0.335379         0.417076        -0.138264
# 2023-01-04          0.632292         0.684541        -0.138264
# 2023-01-05          0.459003         0.708232        -0.234153
# ...                      ...              ...              ...
# 2023-04-06         -0.111587         0.925228        -2.619745
# 2023-04-07         -0.107384         0.921327        -2.619745
# 2023-04-08         -0.103624         0.917320        -2.619745
# 2023-04-09         -0.102526         0.912694        -2.619745
# 2023-04-10         -0.103847         0.908168        -2.619745
#
#             expanding_max_5
# 2023-01-01         0.496714
# 2023-01-02         0.496714
# 2023-01-03         0.647689
# 2023-01-04         1.523030
# 2023-01-05         1.523030
# ...                     ...
# 2023-04-06         1.852278
# 2023-04-07         1.852278
# 2023-04-08         1.852278
# 2023-04-09         1.852278
# 2023-04-10         1.852278
#
# [100 rows x 15 columns]

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

fig, axs = plt.subplots(4, 1,figsize=(12,24)) 

axs[0].xaxis.set_major_formatter(mdates.DateFormatter('%b'))
axs[0].plot(df['expanding_mean_5'])
axs[0].set_title('Subplot 1') 

axs[1].xaxis.set_major_formatter(mdates.DateFormatter('%b'))
axs[1].plot(df['expanding_std_5'])
axs[1].set_title('Subplot 2') 

axs[2].xaxis.set_major_formatter(mdates.DateFormatter('%b'))
axs[2].plot(df['expanding_min_5'])
axs[2].set_title('Subplot 3') 

axs[3].xaxis.set_major_formatter(mdates.DateFormatter('%b'))
axs[3].plot(df['expanding_max_5'])
axs[3].set_title('Subplot 4') 

plt.tight_layout()
plt.show()
